# %%
import os 


import pandas as pd
import numpy as np
import yfinance as yf


WORKSPACE_DIR = os.getenv('WORKSPACE_DIR')
if not os.getcwd().endswith('portfolio_py'):
    os.chdir(f'{WORKSPACE_DIR}/portfolio_py')
print(f'Current Working Directory: {os.getcwd()}')


from utils.config import PROGRAM_START_DATE, PROGRAM_END_DATE
# Out:
# Current Working Directory: /Users/blakeuribe/Desktop/portfolio_py
# Updated on 04/15/2025 5:56

# %%
filtered_df = pd.read_csv('data/clean/filtered_valuation_df.csv')

tickers = list(filtered_df['Tickers'])

# %% [markdown]
# Get data

# %%
# start_date = '2024-06-15'
# end_date = '2025-06-15'

stock_data = yf.download(tickers, start=PROGRAM_START_DATE, end=PROGRAM_END_DATE)["Close"]
stock_data = stock_data.pct_change().dropna()

tbill_data = yf.download('^IRX', start=PROGRAM_START_DATE, end=PROGRAM_END_DATE, auto_adjust=True)['Close']
tbill_data = tbill_data / 100 / 360  # Convert to daily rate
tbill_data = tbill_data.iloc[1:] # to match the dimension of other stock data as we drop na due to pct


spy_data  = yf.download('SPY', start=PROGRAM_START_DATE, end=PROGRAM_END_DATE)["Close"]
spy_data = spy_data.pct_change().dropna()

# stock_data.head()
spy_data
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  10 of 10 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Ticker           SPY
# Date
# 2024-04-16 -0.001824
# 2024-04-17 -0.005918
# 2024-04-18 -0.002058
# 2024-04-19 -0.008728
# 2024-04-22  0.009209
# ...              ...
# 2025-04-08 -0.015663
# 2025-04-09  0.105019
# 2025-04-10 -0.043819
# 2025-04-11  0.017843
# 2025-04-14  0.009701
#
# [250 rows x 1 columns]

# %%
excess_returns = stock_data.subtract(tbill_data['^IRX'], axis=0)
excess_returns
# Out:
# Ticker           ABT       AEM      FTNT      GRMN        GS       MMM  \
# Date
# 2024-04-16  0.002793  0.004901 -0.004008  0.003738 -0.010173 -0.002884
# 2024-04-17 -0.030454  0.012002  0.002646 -0.008022  0.017619 -0.001134
# 2024-04-18 -0.006095  0.015537 -0.009889 -0.002627 -0.002126  0.005571
# 2024-04-19  0.018948  0.005684 -0.009985 -0.008673  0.002062  0.008490
# 2024-04-22 -0.002103 -0.024895  0.004428  0.010605  0.032899  0.003648
# ...              ...       ...       ...       ...       ...       ...
# 2025-04-08 -0.007404  0.004903  0.001589 -0.040092 -0.007184 -0.010929
# 2025-04-09  0.024812  0.056509  0.133518  0.109771  0.118116  0.087646
# 2025-04-10 -0.020110  0.054231 -0.036242 -0.030629 -0.052490 -0.038795
# 2025-04-11  0.018999  0.054567  0.014522  0.015673  0.009356  0.022294
# 2025-04-14  0.008395  0.006173 -0.009121  0.012108  0.019178  0.000325
#
# Ticker          MPLX        MS       NEM      TMUS
# Date
# 2024-04-16 -0.005163  0.024570 -0.008730 -0.000333
# 2024-04-17  0.008175  0.010400  0.011662  0.001732
# 2024-04-18  0.005356  0.001853 -0.000405  0.004602
# 2024-04-19  0.011543  0.004286  0.012046  0.009055
# 2024-04-22  0.012391  0.015627 -0.040125  0.000039
# ...              ...       ...       ...       ...
# 2025-04-08 -0.011552 -0.006160  0.002113 -0.001616
# 2025-04-09  0.033944  0.113431  0.084180  0.034799
# 2025-04-10 -0.017933 -0.045954  0.044806  0.004670
# 2025-04-11  0.016335  0.014332  0.078996  0.009839
# 2025-04-14  0.029143  0.009040 -0.003391  0.015231
#
# [250 rows x 10 columns]

# %% [markdown]
# Need to do poly fit

# %%
excess_returns['ABT'].values
# Out:
# array([ 2.79340326e-03, -3.04540686e-02, -6.09475620e-03,  1.89481342e-02,
#        -2.10317637e-03,  4.71094500e-03, -6.65220797e-03, -4.26292621e-04,
#         6.12435959e-03, -2.56357059e-03, -1.22647283e-02,  2.87398215e-03,
#        -3.62657600e-03, -3.34170748e-04, -2.60077715e-03,  4.87140690e-03,
#        -1.17308773e-02, -2.71845918e-03,  5.23075806e-04,  1.40876786e-04,
#        -7.39932754e-03,  5.43085276e-03,  2.53141455e-03, -7.58326733e-03,
#        -8.59981271e-03, -2.56787579e-03,  1.79196759e-02, -5.77434111e-03,
#        -2.83221803e-03, -1.93857901e-02, -1.21123174e-02,  9.88086976e-03,
#         4.27740419e-03,  6.50860832e-03,  5.29814867e-03, -2.07913952e-03,
#         9.92916179e-03,  3.15991646e-02, -9.82045771e-04, -1.57751007e-02,
#        -1.36604037e-02, -9.05535839e-03,  2.07780914e-03, -2.36407119e-03,
#         5.07450648e-03,  2.46650286e-02, -8.12086490e-03, -4.11745518e-03,
#         1.65919267e-03, -5.92784675e-03, -2.33791071e-03, -7.21606315e-03,
#        -6.97776568e-03, -1.45222227e-04, -8.57546744e-03,  1.63700309e-02,
#        -1.84106243e-02, -4.84563541e-03,  1.37275496e-02,  1.08210441e-02,
#         2.39573755e-04, -6.99296308e-03, -2.47527774e-03,  1.89367365e-02,
#        -4.41831906e-02,  1.94420844e-02,  1.64195562e-02,  1.78453267e-03,
#         3.19965172e-02, -1.22634086e-02, -6.93828516e-03, -4.60891463e-03,
#         5.10697256e-03,  5.74416656e-03,  3.95974376e-02,  1.03913570e-02,
#        -2.42174990e-02,  7.86775112e-03,  3.87713849e-03, -1.77845135e-03,
#        -9.70725300e-03, -8.51175705e-03,  3.94111209e-03,  1.51033141e-02,
#         9.41392327e-03,  3.99883988e-04,  7.96746997e-03, -1.02381854e-02,
#         5.45821088e-03,  6.23440322e-03,  5.12434642e-03, -5.01477437e-05,
#         3.41123853e-03, -1.90594766e-03, -1.37795981e-03,  4.38483507e-03,
#         1.21335703e-02, -2.40500329e-03, -1.15006971e-02,  6.58337689e-03,
#         2.24356852e-02,  5.70605474e-03, -4.49038528e-03,  1.83818544e-03,
#        -3.81283804e-03,  1.04351614e-02,  4.11909643e-03, -2.76402754e-02,
#        -6.48198865e-03, -4.06843170e-03,  9.63742785e-03, -1.29286702e-02,
#        -6.56545269e-03,  9.41559630e-04, -2.78570339e-03,  1.39282534e-02,
#        -4.07159047e-03,  5.80276542e-04, -1.25315867e-02,  3.52801220e-03,
#         6.26635184e-03,  1.10774851e-02,  1.13892942e-02, -2.97177684e-03,
#         4.19903535e-03,  9.60582085e-03, -5.69523589e-03,  1.51269474e-02,
#         4.68706041e-04,  1.25983083e-02, -2.02277019e-02, -7.56144678e-03,
#         7.53934273e-03, -4.14141003e-03, -2.00326160e-02, -1.43782356e-03,
#        -5.99796358e-03,  9.13522602e-03, -9.55951347e-03,  4.60099291e-02,
#        -8.13282469e-03,  5.57126764e-04, -8.02251846e-03, -1.29651874e-02,
#         1.10652313e-02,  1.67859910e-03, -3.20497610e-03, -6.13371667e-03,
#        -6.25615857e-03,  7.44119550e-03,  1.24748017e-02, -2.08223213e-03,
#        -1.03675345e-02,  1.13499143e-02,  4.14137081e-03,  3.01955502e-03,
#        -1.56112915e-03,  8.27082381e-03, -1.63474017e-03, -1.66241075e-02,
#        -4.57270042e-03, -2.87245553e-03, -3.39699425e-03, -3.27172702e-05,
#        -6.17463985e-03,  5.10290819e-03, -1.18931705e-02, -2.57034980e-03,
#        -4.33290033e-03, -6.82051293e-03,  5.83136322e-03, -1.21220960e-02,
#         4.26041610e-03,  1.59833457e-02,  5.83195641e-04,  3.82006735e-03,
#         4.32689650e-03, -2.54511924e-03, -1.91612625e-02,  2.63134923e-03,
#         2.80058632e-03,  3.32155273e-03, -7.05660376e-03,  3.06795209e-03,
#         7.37874558e-03, -1.70972710e-02,  7.71834474e-03, -1.61901446e-03,
#        -1.19463901e-02,  2.51759947e-02, -3.89137622e-03,  2.90515572e-02,
#         8.35960583e-03,  4.60708465e-02,  1.45723404e-02,  3.50751195e-02,
#        -1.58776873e-02,  3.57313652e-03,  7.31381874e-03, -6.94812891e-03,
#         3.94832345e-03,  4.94336849e-03,  2.28110034e-02, -2.91947325e-02,
#         6.51181633e-03,  1.72373876e-02,  8.72732931e-04, -7.34506119e-03,
#         9.84530701e-03, -9.07056071e-03, -3.40932525e-03,  1.48622160e-02,
#         7.75409324e-03,  1.30244929e-02,  1.05963438e-04,  6.33073099e-03,
#         9.14333675e-04, -7.78594932e-04,  1.56339481e-02,  1.58968879e-02,
#        -1.89440518e-02,  8.28054929e-04, -1.92146926e-02,  1.51336753e-02,
#         1.48790070e-03, -3.43331880e-02, -1.80571256e-02, -3.10998069e-03,
#        -2.45985226e-02,  7.22326615e-03, -1.06148250e-02,  8.75140043e-03,
#        -5.13896839e-03, -3.58684324e-03,  6.77002262e-03, -1.27724100e-02,
#         7.92505390e-03,  3.73214887e-02, -4.15136273e-03,  1.38721091e-02,
#        -7.35370294e-03,  1.70569819e-03, -2.39004995e-03, -5.47383121e-02,
#         3.25987899e-03, -7.40424512e-03,  2.48119605e-02, -2.01102966e-02,
#         1.89994382e-02,  8.39544852e-03])

# %%
polyfits = {} # reads as ticker: [Beta, alpha, residual]

# Loop over each column and fit a polynomial
for col in excess_returns.columns:
    y = excess_returns[col].values
    coeffs = np.polyfit(np.array(spy_data['SPY']), y, 1, full=True)  # returns highest degree first
    polyfits[col] = coeffs[:2]

# %%
polyfits
# Out:
# {'ABT': (array([0.23201908, 0.00057024]), array([0.0399995])),
#  'AEM': (array([0.57602072, 0.0025575 ]), array([0.08975816])),
#  'FTNT': (array([0.99125449, 0.00142318]), array([0.13626621])),
#  'GRMN': (array([1.00042393, 0.00108378]), array([0.13025021])),
#  'GS': (array([1.32781656e+00, 5.75742959e-04]), array([0.04518196])),
#  'MMM': (array([0.88833471, 0.00143081]), array([0.08798373])),
#  'MPLX': (array([0.51617968, 0.00093644]), array([0.02588999])),
#  'MS': (array([1.28847372e+00, 6.22829306e-04]), array([0.04726513])),
#  'NEM': (array([0.71304413, 0.0013905 ]), array([0.12421643])),
#  'TMUS': (array([0.32985076, 0.001892  ]), array([0.04852548]))}

# %%
from utils.finance_utils import plot_cum_ret
# Out:
# ---------------------------------
# finance_utils.py successfully loaded, updated last April. 29 2025 4:55
# ---------------------------------

# %%
spy_data
# Out:
# Ticker           SPY
# Date
# 2024-04-16 -0.001824
# 2024-04-17 -0.005918
# 2024-04-18 -0.002058
# 2024-04-19 -0.008728
# 2024-04-22  0.009209
# ...              ...
# 2025-04-08 -0.015663
# 2025-04-09  0.105019
# 2025-04-10 -0.043819
# 2025-04-11  0.017843
# 2025-04-14  0.009701
#
# [250 rows x 1 columns]

# %%
stock_data
# Out:
# Ticker           ABT       AEM      FTNT      GRMN        GS       MMM  \
# Date
# 2024-04-16  0.002939  0.005046 -0.003862  0.003883 -0.010028 -0.002738
# 2024-04-17 -0.030309  0.012148  0.002792 -0.007877  0.017764 -0.000989
# 2024-04-18 -0.005949  0.015683 -0.009743 -0.002481 -0.001981  0.005717
# 2024-04-19  0.019094  0.005829 -0.009839 -0.008527  0.002208  0.008636
# 2024-04-22 -0.001957 -0.024749  0.004574  0.010751  0.033045  0.003793
# ...              ...       ...       ...       ...       ...       ...
# 2025-04-08 -0.007288  0.005019  0.001705 -0.039976 -0.007068 -0.010813
# 2025-04-09  0.024929  0.056626  0.133636  0.109889  0.118234  0.087763
# 2025-04-10 -0.019994  0.054348 -0.036125 -0.030512 -0.052373 -0.038678
# 2025-04-11  0.019116  0.054684  0.014639  0.015790  0.009473  0.022411
# 2025-04-14  0.008512  0.006290 -0.009004  0.012225  0.019295  0.000441
#
# Ticker          MPLX        MS       NEM      TMUS
# Date
# 2024-04-16 -0.005018  0.024716 -0.008585 -0.000188
# 2024-04-17  0.008321  0.010545  0.011808  0.001877
# 2024-04-18  0.005501  0.001998 -0.000259  0.004747
# 2024-04-19  0.011689  0.004432  0.012192  0.009201
# 2024-04-22  0.012537  0.015773 -0.039979  0.000185
# ...              ...       ...       ...       ...
# 2025-04-08 -0.011436 -0.006044  0.002229 -0.001500
# 2025-04-09  0.034062  0.113548  0.084297  0.034917
# 2025-04-10 -0.017816 -0.045837  0.044923  0.004786
# 2025-04-11  0.016452  0.014449  0.079113  0.009956
# 2025-04-14  0.029259  0.009156 -0.003275  0.015348
#
# [250 rows x 10 columns]
