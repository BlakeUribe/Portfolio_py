# %% [markdown]
# This Notebook will find optimal wieghts using MPT, then will back test those wieghts 1 year fowrad from data collections

# %%
import time
import os 

start_time = time.time() # measure run time

WORKSPACE_DIR = os.getenv('WORKSPACE_DIR')
if not os.getcwd().endswith('portfolio_py'):
    os.chdir(f'{WORKSPACE_DIR}/portfolio_py')
print(f'Current Working Directory: {os.getcwd()}')
# Out:
# Current Working Directory: /Users/blakeuribe/Desktop/portfolio_py

# %% [markdown]
# Get Back Test Dates

# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta
from utils.config import PROGRAM_START_DATE, PROGRAM_END_DATE, mpt_stocks_for_profit, mpt_stocks_for_sharpe


from utils.finance_utils import backtest_portfolio, plot_cum_ret
from utils.models import MonteCarloSim

date_obj = datetime.strptime(PROGRAM_END_DATE, "%Y-%m-%d")  # Convert string to datetime objectb
backtest_end = date_obj + relativedelta(years=1)

backtest_start = PROGRAM_END_DATE
# Out:
# Updated on 06/04/2025 5:56
#
# ---------------------------------
# finance_utils.py successfully loaded, updated last April. 29 2025 4:55
# ---------------------------------
#
#
#
# ---------------------------------
# models.py successfully loaded, updated last June. 15 2025 4:55
# ---------------------------------

# %% [markdown]
# Conduct MPT

# %% [markdown]
# MOVED MODEL TO model.py, and renamed as monter carlo sim

# %%
# print('--MPT on High Profit--')
optimizer_for_high_profit = MonteCarloSim(mpt_stocks_for_profit, start_date=PROGRAM_START_DATE, end_date=PROGRAM_END_DATE)
optimizer_for_high_profit.simulate_portfolios()
optimizer_for_high_profit.plot_efficient_frontier()
tangecy_portfolio_for_profit_stocks = optimizer_for_high_profit.find_tangency_portfolio()

print('\n--MPT on High Sharpe--')
optimizer_for_high_sharpe = MonteCarloSim(mpt_stocks_for_sharpe, start_date=PROGRAM_START_DATE, end_date=PROGRAM_END_DATE)
optimizer_for_high_sharpe.simulate_portfolios()
optimizer_for_high_sharpe.plot_efficient_frontier()
tangecy_portfolio_for_sharpe_stocks = optimizer_for_high_sharpe.find_tangency_portfolio()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  8 of 8 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  8 of 8 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# -- Optimal Portfolio (CAL) --
# Max Sharpe Ratio: 2.4
# Corresponding Return: 0.53
# Corresponding Standard Deviation: 0.2
# Optimal Weights: {'AU': np.float64(0.23395156697731903), 'CWAN': np.float64(0.018018976488386306), 'CALM': np.float64(0.27474361574901734), 'HALO': np.float64(0.04991033680997802), 'KGC': np.float64(0.033262657667598255), 'ANYYY': np.float64(0.15379431919905653), 'MLI': np.float64(0.22377985711608492), 'EPRT': np.float64(0.012538669992559601)}
#
# --MPT on High Sharpe--
# -- Optimal Portfolio (CAL) --
# Max Sharpe Ratio: 2.4
# Corresponding Return: 0.53
# Corresponding Standard Deviation: 0.2
# Optimal Weights: {'AU': np.float64(0.21492519665191853), 'CWAN': np.float64(0.010466769701793307), 'CALM': np.float64(0.25782122674385066), 'HALO': np.float64(0.040391049175325454), 'KGC': np.float64(0.10365064923407556), 'ANYYY': np.float64(0.11563299064410365), 'MLI': np.float64(0.2427489823671149), 'EPRT': np.float64(0.014363135481817875)}

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# pd.Series(optimizer_for_high_sharpe.returns).hist(bins=100)
optimizer_for_high_sharpe.spy_lr['SPY'].hist(bins=50)
# Out:
# <Axes: >

# %%
import seaborn as sns

sns.histplot(optimizer_for_high_sharpe.stocks_lr, kde=True)
# sns.displot(optimizer_for_high_sharpe.stocks_lr, kind='hist')
# sns.pairplot(optimizer_for_high_sharpe.stocks_lr, corner=True)
# Out:
# <Axes: ylabel='Count'>

# %%
import datetime

program_start_date_obj = datetime.datetime.strptime(backtest_start, '%Y-%m-%d')

# Check if the year is less than 2021
if program_start_date_obj.year < 2021:
    print("Will need to use IRX")
    risk_rate_ticker = '^IRX'
else:
    print("we can use sgov")
    risk_rate_ticker = 'SGOV'
# Out:
# we can use sgov

# %%
from utils.finance_utils import find_lending_or_borrowing_portfolio


# Benchmark Metrics
spy_return = optimizer_for_high_sharpe.spy_return.iloc[0]
spy_std = optimizer_for_high_sharpe.spy_std.iloc[0]
risk_free_rate = optimizer_for_high_sharpe.risk_free_rate.iloc[0] # Optimizer uses mean rate

# Info for high profit stocks
stock_weight_dict_profit = tangecy_portfolio_for_profit_stocks[0]
tangecy_portfolio_metrics_dict_profit = tangecy_portfolio_for_profit_stocks[1]

# Info for high profit stocks
stock_weight_dict_sharpe = tangecy_portfolio_for_sharpe_stocks[0]
tangecy_portfolio_metrics_dict_sharpe = tangecy_portfolio_for_sharpe_stocks[1]


# Find lending or borrowing for 
portfolio_allocation_high_profit = find_lending_or_borrowing_portfolio(
    tangecy_portfolio_metrics_dict_profit['Corresponding Return'],
    tangecy_portfolio_metrics_dict_profit['Corresponding Standard Deviation'],
    risk_free_rate,
    spy_std,
    list(stock_weight_dict_profit.keys()),
    list(stock_weight_dict_profit.values()),
    add_margin=True,
    risk_free_proxy=risk_rate_ticker
    )

portfolio_allocation_high_sharpe = find_lending_or_borrowing_portfolio(
    tangecy_portfolio_metrics_dict_sharpe['Corresponding Return'],
    tangecy_portfolio_metrics_dict_sharpe['Corresponding Standard Deviation'],
    risk_free_rate,
    spy_std,
    list(stock_weight_dict_sharpe.keys()),
    list(stock_weight_dict_sharpe.values()),
    add_margin=True,
    risk_free_proxy=risk_rate_ticker
    )
portfolio_allocation_high_sharpe
# Out:
# {'Risky Asset Weight': np.float64(0.9717743686267484),
#  'Risk-Free Asset Weight': np.float64(0.028225631373251625),
#  'Stocks': ['AU',
#   'CWAN',
#   'CALM',
#   'HALO',
#   'KGC',
#   'ANYYY',
#   'MLI',
#   'EPRT',
#   'SGOV'],
#  'Stock Weights': array([0.2088588 , 0.01017134, 0.25054406, 0.03925099, 0.10072504,
#         0.11236918, 0.23589724, 0.01395773, 0.02822563]),
#  'Expected Portfolio Return': np.float64(0.5127199660391464),
#  'Expected Portfolio Standard Deviation': np.float64(0.19438517504703082),
#  'Note': 'Portfolio includes T-bills (expected std > benchmark std).'}

# %% [markdown]
# Begin Back Testing

# %%
print('----Begining Back Test----')
print(f'Back Test starts on: {backtest_start}')
print(f'Back Test ends on: {backtest_end}')

paper_value = 100_000
backtest_spy_return = backtest_portfolio(['spy'], 1, [1], start_date=backtest_start, end_date=backtest_end)-1

# Run the backtest
backtest_on_high_profit = backtest_portfolio(portfolio_allocation_high_profit['Stocks'], paper_value, portfolio_allocation_high_profit['Stock Weights'], start_date=backtest_start, end_date=backtest_end)
backtest_on_high_sharpe = backtest_portfolio(portfolio_allocation_high_sharpe['Stocks'], paper_value, portfolio_allocation_high_sharpe['Stock Weights'], start_date=backtest_start, end_date=backtest_end)

plot_cum_ret(portfolio_allocation_high_sharpe['Stocks'], portfolio_allocation_high_sharpe['Stock Weights'], start_date='2024-03-01', end_date=backtest_end)
plot_cum_ret(portfolio_allocation_high_profit['Stocks'], portfolio_allocation_high_profit['Stock Weights'], start_date='2024-03-01', end_date=backtest_end)
# Out:
# ----Begining Back Test----
# Back Test starts on: 2025-04-15
# Back Test ends on: 2026-04-15 00:00:00
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  10 of 10 completed
# [*********************100%***********************]  10 of 10 completed

# %% [markdown]
# Record Results

# %%
import pandas as pd
import os

# Define file path
file_path = f"{WORKSPACE_DIR}/portfolio_py/data/clean/backtest_results.csv"

# Check if file exists
if os.path.exists(file_path):
    # Load existing data
    backtest_df = pd.read_csv(file_path)
else:
    # Create a new DataFrame if the file doesn't exist
    backtest_df = pd.DataFrame(columns=[
        "Data_Collection_Start", "Data_Collection_End",
        "Backtest_Start", "Backtest_End",
        "Stock_Selection_Method", 'Stocks', 'Sharpe', "Starting_Value", "Ending_Value"
    ])

# New entries to append
new_entries = [
    {
        "Data_Collection_Start": PROGRAM_START_DATE,
        "Data_Collection_End": PROGRAM_END_DATE,
        "Backtest_Start": backtest_start,
        "Backtest_End": backtest_end,
        "Stock_Selection_Method": "High Profit Stocks",
        "Stocks": (",".join(portfolio_allocation_high_profit['Stocks'])),
        'Sharpe': tangecy_portfolio_for_profit_stocks[1]['Max Sharpe'],
        "Starting_Value": paper_value,
        "Ending_Value": backtest_on_high_profit,
        'SPY Retrun': backtest_spy_return
    },
    {
        "Data_Collection_Start": PROGRAM_START_DATE,
        "Data_Collection_End": PROGRAM_END_DATE,
        "Backtest_Start": backtest_start,
        "Backtest_End": backtest_end,
        "Stock_Selection_Method": "High Sharpe Ratio Stocks",
        "Stocks": (",".join(portfolio_allocation_high_sharpe['Stocks'])),
        'Sharpe': tangecy_portfolio_for_sharpe_stocks[1]['Max Sharpe'],
        "Starting_Value": paper_value,
        "Ending_Value": backtest_on_high_sharpe,
        'SPY Retrun': backtest_spy_return

    }
]

# Convert new entries to a DataFrame
new_entries_df = pd.DataFrame(new_entries)

# Drop duplicates before writing
backtest_df = pd.concat([backtest_df, new_entries_df], ignore_index=True).drop_duplicates()

# **Append** to the CSV without overwriting
backtest_df.to_csv(file_path, index=False, mode="w")  

print("New rows added successfully (without overwriting)!")
# Out:
# New rows added successfully (without overwriting)!

# %%
backtest_df
# Out:
#    Data_Collection_Start Data_Collection_End Backtest_Start  \
# 0             2020-01-01          2021-01-01     2021-01-01
# 1             2020-01-01          2021-01-01     2021-01-01
# 10         DE,NEM,CQP,BBVA,EQR,BKNG,AVB,AAPL,SGOV  1.511815          100000
# 11         DE,NEM,CQP,GRMN,CSCO,VST,RCL,MPLX,SGOV  1.968748          100000
# 12         DE,NEM,CQP,BBVA,EQR,BKNG,AVB,AAPL,SGOV  1.516444          100000
# 13         DE,NEM,CQP,GRMN,CSCO,VST,RCL,MPLX,SGOV  1.943612          100000
# 14         DE,NEM,CQP,BBVA,EQR,BKNG,AVB,AAPL,SGOV  1.515128          100000
# 15         DE,NEM,CQP,GRMN,CSCO,VST,RCL,MPLX,SGOV  1.979598          100000
# 16     DE,NEM,CQP,BBVA,EQR,BKNG,AVB,AAPL,SGOV,SPY  1.509875          100000
# 17     DE,NEM,CQP,GRMN,CSCO,VST,RCL,MPLX,SGOV,SPY  1.974796          100000
# 18     DE,NEM,CQP,BBVA,EQR,BKNG,AVB,AAPL,SGOV,SPY  1.513385          100000
# 19     DE,NEM,CQP,GRMN,CSCO,VST,RCL,MPLX,SGOV,SPY  1.998009          100000
# 20     DE,NEM,CQP,BBVA,EQR,BKNG,AVB,AAPL,SGOV,SPY  1.514699          100000
# 21     DE,NEM,CQP,GRMN,CSCO,VST,RCL,MPLX,SGOV,SPY  1.967301          100000
# 22         DE,NEM,CQP,BBVA,EQR,BKNG,AVB,AAPL,SGOV  1.512111          100000
# 23         DE,NEM,CQP,GRMN,CSCO,VST,RCL,MPLX,SGOV  1.970060          100000
# 24         DE,NEM,CQP,GRMN,CSCO,VST,RCL,MPLX,SGOV  1.962145          100000
# 25         DE,NEM,CQP,GRMN,CSCO,VST,RCL,MPLX,SGOV  1.957333          100000
# 26         DE,NEM,CQP,GRMN,CSCO,VST,RCL,MPLX,SGOV  1.972408          100000
# 27         DE,NEM,CQP,GRMN,CSCO,VST,RCL,MPLX,SGOV  1.970974          100000
# 28         DE,NEM,CQP,GRMN,CSCO,VST,RCL,MPLX,SGOV  1.949939          100000
# 29        NVS,SNA,RCL,GRMN,LNG,EXEL,KKPNY,PSO,SPY  2.019398          100000
# 30      KKPNY,TPR,GDDY,GGAL,FFIV,PSO,MPLX,LNG,SPY  2.211778          100000
# 31         NVS,SNA,GRMN,LNG,EXEL,PSO,TLN,MPLX,SPY  1.853121          100000
# 32      GDDY,KKPNY,GGAL,FFIV,PSO,MPLX,LNG,MLI,SPY  2.149048          100000
# 33     THC,VRSN,SAN,HSBC,NVS,SNA,MS,GGAL,SGOV,SPY  1.786888          100000
# 34      GDDY,KKPNY,GGAL,FFIV,PSO,MPLX,LNG,MLI,SPY  2.171961          100000
# 35     THC,VRSN,SAN,HSBC,NVS,SNA,MS,GGAL,SGOV,SPY  1.804546          100000
# 36       MKL,THC,MPLX,EXEL,LNG,FFIV,FOXA,GRMN,SPY  2.038691          100000
# 37     THC,VRSN,SAN,HSBC,NVS,SNA,MS,GGAL,SGOV,SPY  1.795002          100000
# 38  MKL,THC,MPLX,EXEL,LNG,FFIV,FOXA,GRMN,SGOV,SPY  2.058224          100000
# 39       EXEL,THC,FUTU,FFIV,FOXA,SNA,MLI,COKE,SPY  2.306937          100000
# 40       EXEL,THC,FUTU,FFIV,FOXA,SNA,MLI,COKE,SPY  2.296056          100000
# 41  EXEL,THC,FUTU,FFIV,FOXA,SNA,MLI,COKE,SGOV,SPY  2.303240          100000
# 42       EXEL,THC,FUTU,FFIV,FOXA,SNA,MLI,COKE,SPY  2.295341          100000
# 43  AU,CWAN,CALM,HALO,KGC,ANYYY,MLI,EPRT,SGOV,SPY  2.406272          100000
# 44  AU,CWAN,CALM,HALO,KGC,ANYYY,MLI,EPRT,SGOV,SPY  2.414372          100000
# 45  AU,CWAN,CALM,HALO,KGC,ANYYY,MLI,EPRT,SGOV,SPY  2.396489          100000
# 46  AU,CWAN,CALM,HALO,KGC,ANYYY,MLI,EPRT,SGOV,SPY  2.397515          100000
#
#      Ending_Value  SPY Retrun
# 0   140446.180568    0.305054
# 1   123186.626152    0.305054
# 2    83619.108449   -0.186464
# 3    86655.415285   -0.186464
# 4   147782.071485    0.255893
# 5   141059.803272    0.255893
# 6   106058.921918    0.021500
# 7   110873.151203    0.021500
# 8    99001.022710   -0.001216
# 9   117355.253744   -0.001216
# 10  101509.295784    0.007050
# 11  100497.515936    0.007050
# 12  101613.485982    0.007050
# 13  101039.993690    0.007050
# 14  103190.244867    0.014816
# 15  101426.209418    0.014816
# 16  102830.796090    0.014816
# 17  101228.467508    0.014816
# 18  103357.471611    0.014816
# 19  102271.777610    0.014816
# 20  102376.166162    0.003847
# 21  101023.530188    0.003847
# 22   92894.273296   -0.094785
# 23   90512.009679   -0.094785
# 24   95497.860457   -0.032437
# 25   95019.040787   -0.032437
# 26   98200.990035   -0.035147
# 27   96216.805686   -0.035147
# 28   95517.977628   -0.035147
# 29  141703.445335    0.000000
# 30  121268.473803    0.000000
# 31  112248.539653   -0.013177
# 32  127516.212631   -0.013177
# 33  102020.583124   -0.013579
# 34  130276.685161   -0.013579
# 35  101209.327554   -0.020833
# 36  108607.489176   -0.020833
# 37  101346.886423   -0.020833
# 38  100099.972968   -0.020833
# 39  102638.108887   -0.020833
# 40  101396.844641   -0.020833
# 41  101971.632293    0.016890
# 42  103776.154573    0.016890
# 43  108063.322934    0.166624
# 44  108714.831833    0.166624
# 45  107867.280104    0.166624
# 46  108335.243075    0.166624

# %%
import numpy as np

chosen_portfolio = {
    k: float(v) if isinstance(v, np.floating) else
       v.tolist() if isinstance(v, np.ndarray) else
       v
    for k, v in portfolio_allocation_high_sharpe.items() # change this vairble based on your prefeneces, and analysis
}

config_path = 'utils/config.py'

# Read current config
with open(config_path, 'r') as file:
    lines = file.readlines()

# Check if chosen_portfolio is already defined
portfolio_exists = any('chosen_portfolio' in line for line in lines)

# Append only if it doesn't exist
if not portfolio_exists:
    with open(config_path, 'a') as file:
        file.write('\n# New Entry from backtesting.ipynb')
        file.write(f'\nchosen_portfolio = {chosen_portfolio}\n')
        print('chosen_portfolio succesfully added')
else:
    print("chosen_portfolio is already defined in config.py")
# Out:
# chosen_portfolio succesfully added
